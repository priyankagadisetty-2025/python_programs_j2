# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional statements
# 2. 'if' statement
# 3. 'elif' statement
# 4. 'else' statement
# 5. 'nested' statement
#
# ```python - if
# if (conditional): #if condition true inside statement are running
#     statement1
#     statements...
# ```
#
# ```python - if,else
# if (condition): #if condition true inside statements are running
#     statement1
#     statement2...n
# else: #if condition fails its went to else statement and print inside statements
#     statement1
#     statement2..n
# ```
#
# ```python - if,elif,else
# if(condition):
#     statements
# elif(condition)
#     statements
# elif(condition)
#     statements
# else(condition)
#     statements
# ```

# %%
# write a program to find the given number is even number?
number=int(input("enter number here"))
if (number%2 == 0):
    print(number, "is even number")
# Out:
# enter number here 85

# %%
# write a program to find the given number is odd number?
number=int(input("please enter number here:"))
if

# %%
#write a program to find thr given number is positive or negative or zero?
n=int(input("enter number here"))
if (n>0):
    print(n,"is positive number")
elif (n<0):
    print(n,"is negative number")
else:
     print(n," is zero")
# Out:
# enter number here 0
# 0  is zero

# %%
#write a program to find the largest number from three number?
v1=int(input("enter first number here:"))
v2=int(input("enter second number here:"))
v3=int(input("enter third number here:"))
if (v1>=v2 and v1>=v3):
    print(v1,"is largest number")
elif (v2>=v1 and v2>=v3):
    print(v2,"is the largest number")
else:
    print(v3,"is the largest number")
# Out:
# enter first number here: 1
# enter second number here: 29
# enter third number here: 19
# 29 is the largest number

# %%
"""
write a program to find the grades based on student marks
1. if marks in between 80 to 100 - A grade
2. if marks in between 60 to 79 - B grade
3. if marks in between 40 to 59 - C grade
4. if marks in between 25 To 39 - D grade
5. if marks in between 0 to 24 - F grade
6. if other than above marks output is - please enter correct marks
"""
marks = int(input("enter student marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"A grade")
elif (marks>=60 and marks<=79):
    print(marks,"B grade")
elif (marks>=40 and marks<=59):
    print(marks,"C grade")
elif (marks>=25 and marks<=39):
    print(marks,"D grade")
elif (marks>=0 and marks<=24):
    print(marks,"is fail")
else:
    print("please enter correct marks")
# Out:
# enter student marks here: 100
# 100 A grade

# %%
#write a program to valid login credential using conditional statements
username=str(input("please enter username here:"))
if (username=="siva@123"):
    print("username is valid")
    password=str(input("please enter password here:"))
    if (password=="sivaji@12345"):
        print("user crednetiles successfully valid")
    else:
        print("password is invalid")
else:
    print("username is invalid")
# Out:
# please enter username here: siva@123
# username is valid
# please enter password here: sivaji@12345
# user crednetiles successfully valid
